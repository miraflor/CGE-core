# %% [markdown]
# # CGE-Core 0.7.0 — Start here
#
# This legacy filename is retained only so links from earlier CGE-Core releases do not break. The **canonical v0.7.0 notebook** is [`01_first_cge.ipynb`](01_first_cge.ipynb).
#
# [![Open the current notebook in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/miraflor/CGE-core/blob/v0.7.0/notebooks/01_first_cge.ipynb)
#
# There is no repository checkout, Git reset, `sys.path`, PATH manipulation, or solver plumbing in this redirect notebook.
